# %%
import pandas as pd
import numpy as np
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC', '^IXIC', '^GDAXI']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source='yahoo', start = '1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088
# 1997-01-08  748.409973  1320.349976  2904.080078

# %%
ind_data.tail()
# Out:
#                   ^GSPC         ^IXIC        ^GDAXI
# Date
# 2022-01-05  4700.580078  15100.169922  16271.750000
# 2022-01-06  4696.049805  15080.860352  16052.030273
# 2022-01-07  4677.029785  14935.900391  15947.740234
# 2022-01-10  4670.290039  14942.830078  15768.269531
# 2022-01-11  4713.069824  15153.448242  15941.809570

# %%
(ind_data / ind_data.iloc[0] * 100).plot(figsize = (15,6));
plt.grid(axis= 'both')
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1

ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2022-01-05 -0.019393 -0.033448  0.007376
# 2022-01-06 -0.000964 -0.001279 -0.013503
# 2022-01-07 -0.004050 -0.009612 -0.006497
# 2022-01-10 -0.001441  0.000464 -0.011254
# 2022-01-11  0.009160  0.014095  0.011006

# %%
annual_ind_returns = ind_returns.mean() * 250

annual_ind_returns
# Out:
# ^GSPC     0.092625
# ^IXIC     0.129207
# ^GDAXI    0.081170
# dtype: float64

# %%
# positive means provided investors with positive return over past 2 decades

# %%
tickers = ['PG', '^GSPC', '^DJI']

data_2 = pd.DataFrame()

for t in tickers:
    data_2[t] = wb.DataReader(t, data_source='yahoo', start = '2007-1-1')['Adj Close']

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2022-01-05  164.210007  4700.580078  36407.109375
# 2022-01-06  162.830002  4696.049805  36236.468750
# 2022-01-07  162.740005  4677.029785  36231.660156
# 2022-01-10  160.520004  4670.290039  36068.871094
# 2022-01-11  158.660004  4713.069824  36252.019531

# %%
(data_2 / data_2.iloc[0] * 100).plot(figsize = (15,6));
plt.grid(axis = 'both')
plt.show()
